# %% [markdown]
# # Importing all the libraries

# %%
import pandas as pd

# %%
import numpy as np

# %%
autos = pd.read_csv("autos.csv", encoding = "Windows-1252")

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %%
autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# ...

# %% [markdown]
# # Starting data cleaning from the column row

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
autos.rename(columns={'yearOfRegistration': 'registration_year',
'monthOfRegistration' : 'registration_month',
'notRepairedDamage' : 'unrepaired_damage',
'dateCreated' : 'ad_created',
'dateCrawled':'date_crawled',
'offerType':'offer_type',
'vehicleType': 'vehicle_type',
'powerPS': 'power_ps',
'fuelType': 'fuel_type',
'nrOfPictures':'pictures_quantity',
'postalCode':'postal_code',
'lastSeen':'last_seen'}, inplace = True)

# %%
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  power_ps   model   odometer  registration_month fuel_type  \
# ...

# %% [markdown]
# #### Columns names are cleaned according to the standards. Converted from the camel case to the snake case

# %%
autos.describe(include= 'all')
# Out:
#                date_crawled         name  seller offer_type  price abtest  \
# count                 50000        50000   50000      50000  50000  50000
# unique                48213        38754       2          2   2357      2
# top     2016-03-11 22:38:16  Ford_Fiesta  privat    Angebot     $0   test
# freq                      3           78   49999      49999   1421  25756
# mean                    NaN          NaN     NaN        NaN    NaN    NaN
# std                     NaN          NaN     NaN        NaN    NaN    NaN
# min                     NaN          NaN     NaN        NaN    NaN    NaN
# 25%                     NaN          NaN     NaN        NaN    NaN    NaN
# 50%                     NaN          NaN     NaN        NaN    NaN    NaN
# 75%                     NaN          NaN     NaN        NaN    NaN    NaN
# max                     NaN          NaN     NaN        NaN    NaN    NaN
#
#        vehicle_type  registration_year  gearbox      power_ps  model  \
# ...

# %%
autos['price'] = autos['price'].str.replace('$','').str.replace(',','').astype(int)

# %%
autos['price'].value_counts()
# Out:
# 0         1421
# 500        781
# 1500       734
# 2500       643
# 1000       639
# 1200       639
# 600        531
# 800        498
# 3500       498
# 2000       460
# 999        434
# 750        433
# 900        420
# 650        419
# 850        410
# 700        395
# 4500       394
# 300        384
# 2200       382
# 950        379
# 1100       376
# 1300       371
# 3000       365
# 550        356
# 1800       355
# 5500       340
# 1250       335
# 350        335
# 1600       327
# 1999       322
#           ...
# 46200        1
# 29600        1
# 13480        1
# 21700        1
# 7373         1
# 3279         1
# 4286         1
# 188          1
# 17830        1
# 9130         1
# 910          1
# 238          1
# 2671         1
# 69900        1
# 151990       1
# 2479         1
# 4510         1
# 86500        1
# 47499        1
# 16998        1
# 27299        1
# 41850        1
# 4780         1
# 686          1
# 6495         1
# 20790        1
# 8970         1
# ...

# %%
autos['odometer_km'] = autos['odometer'].str.replace('km','').str.replace(',','').astype(int)

# %%
autos['odometer_km'].describe()
# Out:
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %%
autos['seller'].value_counts()
# Out:
# privat        49999
# gewerblich        1
# Name: seller, dtype: int64

# %%
autos['offer_type'].value_counts()
# Out:
# Angebot    49999
# Gesuch         1
# Name: offer_type, dtype: int64

# %%
autos['price'].unique()
# Out:
# array([ 5000,  8500,  8990, ...,   385, 22200, 16995])

# %%
autos['price'].describe()
# Out:
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64

# %%
autos['price'].value_counts().sort_index()
# Out:
# 0           1421
# 1            156
# 2              3
# 3              1
# 5              2
# 8              1
# 9              1
# 10             7
# 11             2
# 12             3
# 13             2
# 14             1
# 15             2
# 17             3
# 18             1
# 20             4
# 25             5
# 29             1
# 30             7
# 35             1
# 40             6
# 45             4
# 47             1
# 49             4
# 50            49
# 55             2
# 59             1
# 60             9
# 65             5
# 66             1
#             ...
# 151990         1
# 155000         1
# 163500         1
# 163991         1
# 169000         1
# 169999         1
# 175000         1
# 180000         1
# 190000         1
# 194000         1
# 197000         1
# 198000         1
# 220000         1
# 250000         1
# 259000         1
# 265000         1
# 295000         1
# 299000         1
# 345000         1
# 350000         1
# 999990         1
# ...

# %%
autos = autos[autos['price'].between(1000, 3000000)]

# %%
autos['price'].value_counts().sort_index()
# Out:
# 1000       639
# 1039         1
# 1040         1
# 1049         6
# 1050        95
# 1059         1
# 1070         1
# 1080         6
# 1090         4
# 1095         3
# 1098         1
# 1099        44
# 1100       376
# 1111        39
# 1112         1
# 1119         1
# 1120         2
# 1149        10
# 1150       226
# 1169         1
# 1170         1
# 1180         4
# 1189         1
# 1190        37
# 1195         1
# 1199       126
# 1200       639
# 1201         2
# 1209         1
# 1212         2
#           ...
# 129000       1
# 130000       1
# 135000       1
# 137999       1
# 139997       1
# 145000       1
# 151990       1
# 155000       1
# 163500       1
# 163991       1
# 169000       1
# 169999       1
# 175000       1
# 180000       1
# 190000       1
# 194000       1
# 197000       1
# 198000       1
# 220000       1
# 250000       1
# 259000       1
# 265000       1
# 295000       1
# 299000       1
# 345000       1
# 350000       1
# 999990       1
# ...

# %%
autos['odometer_km'].value_counts().sort_index()
# Out:
# 5000        507
# 10000       228
# 20000       692
# 30000       748
# 40000       795
# 50000       987
# 60000      1099
# 70000      1154
# 80000      1334
# 90000      1569
# 100000     1860
# 125000     4341
# 150000    23317
# Name: odometer_km, dtype: int64

# %% [markdown]
# #### I have cleaned price column and removed some outlying data

# %%
autos['price'].describe()
# Out:
# count    3.863100e+04
# mean     7.397704e+03
# std      1.590025e+04
# min      1.000000e+03
# 25%      2.200000e+03
# 50%      4.350000e+03
# 75%      8.950000e+03
# max      1.300000e+06
# Name: price, dtype: float64

# %%
autos[['date_crawled','ad_created','last_seen']][0:5]
# Out:
#           date_crawled           ad_created            last_seen
# 0  2016-03-26 17:47:46  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 13:38:56  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50

# %%
print(autos['date_crawled'].str[:10])
# Out:
# 0        2016-03-26
# 1        2016-04-04
# 2        2016-03-26
# 3        2016-03-12
# 4        2016-04-01
# 5        2016-03-21
# 7        2016-03-16
# 12       2016-03-31
# 13       2016-03-23
# 14       2016-03-23
# 15       2016-04-01
# 17       2016-03-29
# 19       2016-03-17
# 20       2016-03-05
# 21       2016-03-06
# 22       2016-03-28
# 23       2016-03-10
# 24       2016-04-03
# 28       2016-03-19
# 29       2016-04-02
# 31       2016-03-14
# 33       2016-03-15
# 34       2016-04-05
# 35       2016-03-29
# 36       2016-03-16
# 37       2016-03-23
# 38       2016-03-21
# 39       2016-03-11
# 40       2016-03-07
# 41       2016-03-10
#             ...
# 49962    2016-03-14
# 49963    2016-03-26
# 49964    2016-03-10
# 49965    2016-03-11
# 49966    2016-04-02
# 49967    2016-03-12
# 49968    2016-04-01
# 49969    2016-03-17
# 49970    2016-03-21
# 49972    2016-03-26
# 49973    2016-03-27
# 49975    2016-03-27
# 49976    2016-03-19
# 49977    2016-03-31
# ...

# %%
autos['date_crawled'].str[:10].value_counts(dropna=False).sort_index()
# Out:
# 2016-03-05     987
# 2016-03-06     536
# 2016-03-07    1357
# 2016-03-08    1260
# 2016-03-09    1254
# 2016-03-10    1287
# 2016-03-11    1267
# 2016-03-12    1444
# 2016-03-13     618
# 2016-03-14    1415
# 2016-03-15    1299
# 2016-03-16    1123
# 2016-03-17    1178
# 2016-03-18     496
# 2016-03-19    1357
# 2016-03-20    1474
# 2016-03-21    1441
# 2016-03-22    1257
# 2016-03-23    1244
# 2016-03-24    1121
# 2016-03-25    1179
# 2016-03-26    1279
# 2016-03-27    1213
# 2016-03-28    1366
# 2016-03-29    1313
# 2016-03-30    1277
# 2016-03-31    1213
# 2016-04-01    1337
# 2016-04-02    1402
# 2016-04-03    1512
# 2016-04-04    1425
# 2016-04-05     516
# 2016-04-06     126
# 2016-04-07      58
# Name: date_crawled, dtype: int64

# %%
autos['ad_created'].str[:10].value_counts(dropna=False).sort_index()
# Out:
# 2015-06-11       1
# 2015-08-10       1
# 2015-09-09       1
# 2015-11-10       1
# 2015-12-30       1
# 2016-01-03       1
# 2016-01-07       1
# 2016-01-10       2
# 2016-01-13       1
# 2016-01-14       1
# 2016-01-16       1
# 2016-01-22       1
# 2016-01-27       3
# 2016-01-29       1
# 2016-02-01       1
# 2016-02-02       2
# 2016-02-05       2
# 2016-02-07       1
# 2016-02-09       1
# 2016-02-11       1
# 2016-02-12       2
# 2016-02-14       2
# 2016-02-16       1
# 2016-02-17       1
# 2016-02-18       2
# 2016-02-19       3
# 2016-02-20       1
# 2016-02-21       2
# 2016-02-22       1
# 2016-02-23       4
#               ...
# 2016-03-09    1261
# 2016-03-10    1274
# 2016-03-11    1277
# 2016-03-12    1434
# 2016-03-13     682
# 2016-03-14    1351
# 2016-03-15    1292
# 2016-03-16    1145
# 2016-03-17    1166
# 2016-03-18     513
# 2016-03-19    1316
# 2016-03-20    1478
# 2016-03-21    1452
# 2016-03-22    1249
# 2016-03-23    1234
# 2016-03-24    1121
# ...

# %%
autos['last_seen'].str[:10].value_counts(dropna=False).sort_index()
# Out:
# 2016-03-05      42
# 2016-03-06     138
# 2016-03-07     176
# 2016-03-08     241
# 2016-03-09     344
# 2016-03-10     379
# 2016-03-11     453
# 2016-03-12     857
# 2016-03-13     324
# 2016-03-14     463
# 2016-03-15     579
# 2016-03-16     597
# 2016-03-17    1019
# 2016-03-18     285
# 2016-03-19     564
# 2016-03-20     765
# 2016-03-21     760
# 2016-03-22     803
# 2016-03-23     692
# 2016-03-24     716
# 2016-03-25     686
# 2016-03-26     621
# 2016-03-27     544
# 2016-03-28     751
# 2016-03-29     803
# 2016-03-30     906
# 2016-03-31     878
# 2016-04-01     896
# 2016-04-02     963
# 2016-04-03     944
# 2016-04-04     903
# 2016-04-05    5066
# 2016-04-06    9066
# 2016-04-07    5407
# Name: last_seen, dtype: int64

# %%
autos['registration_year'].describe()
# Out:
# count    38631.000000
# mean      2005.678186
# std         86.679719
# min       1000.000000
# 25%       2001.000000
# 50%       2005.000000
# 75%       2009.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %%
autos['registration_year'].value_counts().sort_index()
# Out:
# 1000       1
# 1001       1
# 1927       1
# 1929       1
# 1931       1
# 1934       2
# 1937       4
# 1938       1
# 1939       1
# 1941       2
# 1943       1
# 1948       1
# 1950       1
# 1951       2
# 1952       1
# 1953       1
# 1954       2
# 1955       2
# 1956       4
# 1957       2
# 1958       3
# 1959       6
# 1960      17
# 1961       6
# 1962       4
# 1963       8
# 1964       9
# 1965      17
# 1966      21
# 1967      25
#         ...
# 1999    1725
# 2000    2001
# 2001    2065
# 2002    2135
# 2003    2477
# 2004    2608
# 2005    2785
# 2006    2651
# 2007    2259
# 2008    2204
# 2009    2077
# 2010    1584
# 2011    1617
# 2012    1306
# 2013     795
# 2014     649
# 2015     361
# 2016     651
# 2017    1008
# 2018     398
# 2019       1
# 2800       1
# 4100       1
# 4500       1
# 5000       2
# 5911       1
# 6200       1
# 8888       1
# 9000       1
# 9999       2
# Name: registration_year, Length: 91, dtype: int64

# %%
autos = autos[autos['registration_year'].between(1920, 2016)]
#cleaning some odd values in the registration year column
#lowest value will be 1927(its safe to remove two odd values: 100 and 1001)
#highest value is 2016 because a car can't be first registered after the listing was seen

# %%
autos['registration_year'].describe()
# Out:
# count    37211.000000
# mean      2003.967563
# std          7.021114
# min       1927.000000
# 25%       2001.000000
# 50%       2005.000000
# 75%       2008.000000
# max       2016.000000
# Name: registration_year, dtype: float64

# %%
autos['registration_year'].value_counts(normalize=True)
# Out:
# 2005    0.074843
# 2006    0.071242
# 2004    0.070087
# 2003    0.066566
# 2007    0.060708
# 2008    0.059230
# 2002    0.057376
# 2009    0.055817
# 2001    0.055494
# 2000    0.053774
# 1999    0.046357
# 2011    0.043455
# 2010    0.042568
# 2012    0.035097
# 1998    0.034479
# 2013    0.021365
# 1997    0.021150
# 2016    0.017495
# 2014    0.017441
# 1996    0.014566
# 1995    0.011905
# 2015    0.009701
# 1994    0.007283
# 1992    0.005885
# 1993    0.005858
# 1991    0.005563
# 1990    0.005079
# 1989    0.003305
# 1988    0.002849
# 1985    0.002150
#           ...
# 1976    0.000564
# 1977    0.000537
# 1975    0.000484
# 1969    0.000484
# 1965    0.000457
# 1960    0.000457
# 1964    0.000242
# 1963    0.000215
# 1959    0.000161
# 1961    0.000161
# 1956    0.000107
# 1962    0.000107
# 1937    0.000107
# 1958    0.000081
# 1954    0.000054
# 1955    0.000054
# 1941    0.000054
# 1957    0.000054
# 1934    0.000054
# 1951    0.000054
# 1953    0.000027
# ...

# %%
autos['brand'].unique()
# Out:
# array(['peugeot', 'bmw', 'volkswagen', 'smart', 'ford', 'chrysler',
#        'audi', 'renault', 'sonstige_autos', 'mazda', 'porsche', 'mini',
#        'mercedes_benz', 'seat', 'toyota', 'opel', 'dacia', 'jeep', 'saab',
#        'volvo', 'nissan', 'jaguar', 'skoda', 'subaru', 'fiat',
#        'mitsubishi', 'chevrolet', 'hyundai', 'honda', 'kia', 'citroen',
#        'suzuki', 'trabant', 'land_rover', 'alfa_romeo', 'rover',
#        'daihatsu', 'daewoo', 'lancia', 'lada'], dtype=object)

# %%
autos['brand'].value_counts(normalize=True)
#for aggregation we will choose brands that have over 5% of the total values
#volkswagen      21%
#bmw             12%
#mercedes_benz   11%
#audi            9%
#opel            8%
#ford            5%
# Out:
# volkswagen        0.210825
# bmw               0.125366
# mercedes_benz     0.111580
# audi              0.097579
# opel              0.089060
# ford              0.058719
# renault           0.037274
# peugeot           0.027895
# fiat              0.021069
# skoda             0.019054
# seat              0.017280
# smart             0.016608
# toyota            0.014619
# mazda             0.014243
# citroen           0.013894
# nissan            0.013625
# mini              0.010884
# hyundai           0.010750
# sonstige_autos    0.010481
# volvo             0.008976
# kia               0.007686
# porsche           0.007471
# honda             0.007337
# mitsubishi        0.006880
# chevrolet         0.006611
# alfa_romeo        0.006235
# suzuki            0.005724
# dacia             0.003279
# chrysler          0.003171
# jeep              0.002768
# land_rover        0.002634
# jaguar            0.001854
# subaru            0.001720
# daihatsu          0.001693
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37211 entries, 0 to 49999
# Data columns (total 21 columns):
# date_crawled          37211 non-null object
# name                  37211 non-null object
# seller                37211 non-null object
# offer_type            37211 non-null object
# price                 37211 non-null int64
# abtest                37211 non-null object
# vehicle_type          35873 non-null object
# registration_year     37211 non-null int64
# gearbox               35936 non-null object
# power_ps              37211 non-null int64
# model                 35775 non-null object
# odometer              37211 non-null object
# registration_month    37211 non-null int64
# fuel_type             35374 non-null object
# brand                 37211 non-null object
# unrepaired_damage     32027 non-null object
# ad_created            37211 non-null object
# pictures_quantity     37211 non-null int64
# postal_code           37211 non-null int64
# ...

# %%
top_brands = {}
brands = ['volkswagen', 'bmw', 'mercedes_benz', 'audi', 'opel', 'ford' ]

# %%
for b in brands:
    selected_rows = autos[autos['brand'] == b]
    price_mean = selected_rows['price'].mean()
    top_brands[b] = price_mean
print(top_brands)
# Out:
# {'mercedes_benz': 9302.614402697494, 'bmw': 9381.89174705252, 'ford': 5786.703432494279, 'volkswagen': 6898.376545570427, 'opel': 4219.954737477368, 'audi': 10322.269347287249}

# %% [markdown]
# #The most popular selling cars on this eBay site are in two pricing tiers:
# #High-price tier (Audi, Mercedes-Benz, BMW)
# #Mid-price tier (Volkswagen, Ford, Opel)

# %%
mileage_km = {}
for b in brands:
    selected_row = autos[autos['brand'] == b]
    mileage_mean = selected_row['odometer_km'].mean()
    mileage_km[b] = mileage_mean
print(mileage_km)
# Out:
# {'mercedes_benz': 130062.6204238921, 'bmw': 132005.359056806, 'ford': 119622.42562929062, 'volkswagen': 125771.82919056724, 'opel': 123952.92697646348, 'audi': 127491.04929771413}

# %%
#series constructor
bmp_series = pd.Series(top_brands)
print(bmp_series)
# Out:
# audi             10322.269347
# bmw               9381.891747
# ford              5786.703432
# mercedes_benz     9302.614403
# opel              4219.954737
# volkswagen        6898.376546
# dtype: float64

# %%
df = pd.DataFrame(bmp_series, columns=['mean_price'])
df
# Out:
#                  mean_price
# audi           10322.269347
# bmw             9381.891747
# ford            5786.703432
# mercedes_benz   9302.614403
# opel            4219.954737
# volkswagen      6898.376546

# %%
bmp_2series = pd.Series(mileage_km)
df['mean_mileage'] = bmp_2series
df
# Out:
#                  mean_price   mean_mileage
# audi           10322.269347  127491.049298
# bmw             9381.891747  132005.359057
# ford            5786.703432  119622.425629
# mercedes_benz   9302.614403  130062.620424
# opel            4219.954737  123952.926976
# volkswagen      6898.376546  125771.829191

# %% [markdown]
# #Although the mean mileage for each brand is roughly the same, the average price for the brands varies greatly.

# %%
autos['unrepaired_damage'].unique()
# Out:
# array(['nein', nan, 'ja'], dtype=object)

# %%
#translating some columns from german to english
unrepaired_damage_dict = {'nein':'no', 'ja':'yes', 'yes':'yes'}
autos['unrepaired_damage'] = autos['unrepaired_damage'].map(unrepaired_damage_dict)
autos['unrepaired_damage']
# Out:
# 0         no
# 1         no
# 2         no
# 3         no
# 4         no
# 5        NaN
# 7         no
# 12        no
# 13        no
# 14       NaN
# 15        no
# 17        no
# 19        no
# 20       NaN
# 21        no
# 22        no
# 23        no
# 24        no
# 28       yes
# 29        no
# 31        no
# 33        no
# 34       NaN
# 35        no
# 36        no
# 37        no
# 38        no
# 39        no
# 40        no
# 41        no
#         ...
# 49962    yes
# 49963     no
# 49964    NaN
# 49965     no
# 49966    yes
# 49967    NaN
# 49968     no
# 49969     no
# 49970     no
# 49972    yes
# 49973     no
# 49975     no
# 49976     no
# 49977     no
# 49979     no
# 49981     no
# 49982    NaN
# 49985    NaN
# 49986     no
# 49987     no
# 49988     no
# 49990     no
# 49992     no
# 49993    NaN
# 49994     no
# 49995     no
# 49996     no
# 49997     no
# 49998     no
# 49999     no
# Name: unrepaired_damage, Length: 37211, dtype: object

# %%
autos['vehicle_type'].unique()
# Out:
# array(['bus', 'limousine', 'kleinwagen', 'kombi', 'coupe', 'suv',
#        'cabrio', nan, 'andere'], dtype=object)

# %%
vehicle_type_dict = {'bus':'bus', 'kleinwagen':'compact car', 'kombi':'estate car', 'cabrio': 'cabriolet', 'andere':'other'}
autos['vehicle_type'] = autos['vehicle_type'].map(vehicle_type_dict)
autos['vehicle_type']
# Out:
# 0                bus
# 1                NaN
# 2                NaN
# 3        compact car
# 4         estate car
# 5                bus
# 7                NaN
# 12       compact car
# 13               NaN
# 14       compact car
# 15               NaN
# 17               NaN
# 19               NaN
# 20        estate car
# 21         cabriolet
# 22         cabriolet
# 23               bus
# 24               NaN
# 28       compact car
# 29        estate car
# 31        estate car
# 33        estate car
# 34        estate car
# 35        estate car
# 36        estate car
# 37               bus
# 38               NaN
# 39        estate car
# 40         cabriolet
# 41        estate car
#             ...
# 49962            NaN
# 49963            bus
# 49964     estate car
# 49965            NaN
# 49966    compact car
# 49967     estate car
# 49968            NaN
# 49969            NaN
# 49970            bus
# 49972            bus
# 49973      cabriolet
# 49975    compact car
# ...

# %%
#Convert the dates to be uniform numeric data
autos['last_seen'] = autos['last_seen'].str[:10].str.split('-').str.join('').astype(int)
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-53-9df254eda2ac> in <module>()
#       1 #Convert the dates to be uniform numeric data
# ----> 2 autos['last_seen'] = autos['last_seen'].str[:10].str.split('-').str.join('').astype(int)
#       3 autos['last_seen'].info()
#
# /dataquest/system/env/python3/lib/python3.4/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3608         if (name in self._internal_names_set or name in self._metadata or
#    3609                 name in self._accessors):
# -> 3610             return object.__getattribute__(self, name)
#    3611         else:
#    3612             if name in self._info_axis:
#
# /dataquest/system/env/python3/lib/python3.4/site-packages/pandas/core/accessor.py in __get__(self, instance, owner)
#      52             # this ensures that Series.str.<method> is well defined
#      53             return self.accessor_cls
# ---> 54         return self.construct_accessor(instance)
#      55
# ...

# %%
autos['last_seen'].unique()
# Out:
# array([20160406, 20160315, 20160401, 20160407, 20160402, 20160405,
#        20160317, 20160307, 20160316, 20160328, 20160312, 20160324,
#        20160404, 20160330, 20160320, 20160403, 20160314, 20160326,
#        20160310, 20160327, 20160329, 20160311, 20160331, 20160322,
#        20160323, 20160325, 20160319, 20160321, 20160313, 20160308,
#        20160318, 20160309, 20160305, 20160306])

# %%
autos
# Out:
#               date_crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 12     2016-03-31 19:48:22  Smart_smart_fortwo_coupe_softouch_pure_MHD_Pan...
# 13     2016-03-23 10:48:32                                 Audi_A3_1.6_tuning
# 14     2016-03-23 11:50:46  Renault_Clio_3__Dynamique_1.2__16_V;_viele_Ver...
# 15     2016-04-01 12:06:20        Corvette_C3_Coupe_T_Top_Crossfire_Injection
# ...

# %%
autos = autos.drop(['seller','offer_type','odometer'],axis = 1)

# %%
autos
# Out:
#               date_crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 12     2016-03-31 19:48:22  Smart_smart_fortwo_coupe_softouch_pure_MHD_Pan...
# 13     2016-03-23 10:48:32                                 Audi_A3_1.6_tuning
# 14     2016-03-23 11:50:46  Renault_Clio_3__Dynamique_1.2__16_V;_viele_Ver...
# 15     2016-04-01 12:06:20        Corvette_C3_Coupe_T_Top_Crossfire_Injection
# ...

# %%
autos['gearbox'].unique()
# Out:
# array(['manuell', 'automatik', nan], dtype=object)

# %%
gearbox_dict = {'manual':'manual','manuell': 'manual', 'automatik':'automatic'}
autos['gearbox'] = autos['gearbox'].map(gearbox_dict)
autos['gearbox']
# Out:
# 0           manual
# 1        automatic
# 2           manual
# 3        automatic
# 4           manual
# 5        automatic
# 7           manual
# 12       automatic
# 13          manual
# 14          manual
# 15       automatic
# 17          manual
# 19          manual
# 20          manual
# 21          manual
# 22          manual
# 23          manual
# 24       automatic
# 28          manual
# 29       automatic
# 31       automatic
# 33          manual
# 34       automatic
# 35          manual
# 36          manual
# 37          manual
# 38          manual
# 39       automatic
# 40          manual
# 41          manual
#            ...
# 49962       manual
# 49963       manual
# 49964    automatic
# 49965       manual
# 49966       manual
# 49967       manual
# 49968    automatic
# 49969       manual
# 49970    automatic
# 49972    automatic
# 49973       manual
# 49975    automatic
# 49976    automatic
# 49977       manual
# 49979       manual
# 49981       manual
# ...

# %%
top_brand_model = {}
for b in brands:
    sel_row = autos[autos['brand'] == b]
    top_models = selected_row['model']
    for m in top_models:
        top_brand_model[b] = top_models
print(top_brand_model)
# Out:
# {'mercedes_benz': 4          focus
# 35        mondeo
# 36        mondeo
# 54         focus
# 110       galaxy
# 121        focus
# 138        c_max
# 215        focus
# 220           ka
# 223       fiesta
# 243        focus
# 251       mondeo
# 257       mondeo
# 285        focus
# 307        focus
# 311        s_max
# 324          NaN
# 352        focus
# 358        focus
# 388       galaxy
# 406       fiesta
# 417       mondeo
# 476      transit
# 503       mondeo
# 514        focus
# 525      mustang
# 529        focus
# 556       galaxy
# 575       andere
# 596       galaxy
#           ...
# 49251     fiesta
# 49269     mondeo
# 49296     fiesta
# 49300      focus
# 49312     fiesta
# 49317      focus
# 49341     fiesta
# 49361     andere
# 49375      focus
# 49402     galaxy
# 49412     mondeo
# 49430    mustang
# 49459     mondeo
# 49495      focus
# 49497     mondeo
# 49543      focus
# 49603    mustang
# 49608     fiesta
# 49656     mondeo
# 49664     mondeo
# ...

# %%
autos['model'].value_counts()
# Out:
# golf                  2918
# andere                2668
# 3er                   2285
# passat                1152
# a4                    1092
# 5er                   1065
# c_klasse              1034
# astra                  981
# polo                   947
# e_klasse               890
# corsa                  826
# a3                     768
# a6                     753
# transporter            646
# focus                  583
# fortwo                 514
# 1er                    511
# 2_reihe                504
# a_klasse               443
# touran                 433
# fiesta                 429
# zafira                 362
# 3_reihe                339
# mondeo                 310
# vectra                 305
# clio                   303
# x_reihe                296
# twingo                 290
# octavia                288
# fabia                  272
#                       ...
# 300c                    10
# gl                      10
# mii                     10
# ...
